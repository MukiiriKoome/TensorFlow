# %% [markdown]
# ## ARTIFICIAL NEURAL NETWORKS

# %%
#Keras Sequential Model

# %%
# !pip install tensorflow

# %%
from tensorflow.keras import backend as K
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Activation
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import categorical_crossentropy

# %%
model = Sequential([
    Dense(16, input_shape=(1,), activation='relu'),
    Dense(32, activation='relu'),
    Dense(2, activation='softmax'),
])

# %%
model.compile(Adam(learning_rate=.0001),loss='sparse_categorical_crossentropy',metrics=['accuracy'])

# %%
import numpy as np

# %%
# Load the array from the file
scaled_train_samples = np.load('scaled_train_samples.npy')
train_labels = np.load('train_labels.npy')

# %%
model.fit(scaled_train_samples, train_labels, validation_split=0.20, batch_size=10, epochs=20, shuffle=True, verbose=2)
# Out:
# Epoch 1/20
# 168/168 - 1s - 5ms/step - accuracy: 0.9732 - loss: 0.1713 - val_accuracy: 0.7429 - val_loss: 0.6852
# Epoch 2/20
# 168/168 - 1s - 4ms/step - accuracy: 0.9732 - loss: 0.1622 - val_accuracy: 0.7429 - val_loss: 0.7021
# Epoch 3/20
# 168/168 - 1s - 4ms/step - accuracy: 0.9774 - loss: 0.1539 - val_accuracy: 0.7571 - val_loss: 0.7197
# Epoch 4/20
# 168/168 - 1s - 3ms/step - accuracy: 0.9792 - loss: 0.1464 - val_accuracy: 0.7571 - val_loss: 0.7366
# Epoch 5/20
# 168/168 - 1s - 3ms/step - accuracy: 0.9815 - loss: 0.1395 - val_accuracy: 0.7571 - val_loss: 0.7564
# Epoch 6/20
# 168/168 - 1s - 3ms/step - accuracy: 0.9815 - loss: 0.1332 - val_accuracy: 0.7571 - val_loss: 0.7758
# Epoch 7/20
# 168/168 - 1s - 3ms/step - accuracy: 0.9821 - loss: 0.1275 - val_accuracy: 0.7571 - val_loss: 0.7942
# Epoch 8/20
# 168/168 - 1s - 3ms/step - accuracy: 0.9821 - loss: 0.1222 - val_accuracy: 0.7571 - val_loss: 0.8113
# Epoch 9/20
# ...

# %%
pip install imageio
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import imageio
import matplotlib.pyplot as plt
# %matplotlib inline

img = np.expand_dims(imageio.imread('NN.png'),0)
plt.imshow(img[0])
plt.axis('off')
# Out:
# /tmp/ipykernel_25720/1721292944.py:6: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   img = np.expand_dims(imageio.imread('NN.png'),0)
# (-0.5, 799.5, 503.5, -0.5)

# %%
# Load test samples data
scaled_test_samples = np.load("scaled_test_samples.npy")

# %%
model.predict(scaled_test_samples, batch_size=10, verbose=0)
